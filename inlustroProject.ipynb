# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import joblib
import os

# %%
df = pd.read_csv('/content/Data_change.csv')
df
# Out:
#       Unnamed: 0        State         District                   Market  \
# 0              0        Bihar           Araria               Forbesganj
# 1              1        Bihar       Kishanganj              Bahadurganj
# 2              2        Bihar        Madhubani                 Jainagar
# 3              3        Bihar           Rohtas                   Natwar
# 4              4   Chandigarh       Chandigarh  Chandigarh(Grain/Fruit)
# ...          ...          ...              ...                      ...
# 7934        7934  West Bengal  Purba Bardhaman                    Kalna
# 7935        7935  West Bengal  Purba Bardhaman                    Kalna
# 7936        7936  West Bengal  Purba Bardhaman                   Memari
# 7937        7937  West Bengal  Purba Bardhaman                   Memari
# 7938        7938  West Bengal         Puruliya                  Purulia
#
#           Commodity        Variety Grade Arrival_Date  Min_x0020_Price  \
# 0            Potato          Jyoti   FAQ   01-09-2024             2200
# 1            Potato          Jyoti   FAQ   01-09-2024             2500
# 2             Onion         Medium   FAQ   01-09-2024             4200
# 3            Potato          Jyoti   FAQ   01-09-2024             2400
# 4     Ginger(Green)            FAQ   FAQ   01-09-2024             3000
# ...             ...            ...   ...          ...              ...
# 7934   Green Chilli            FAQ   FAQ   01-09-2024             7800
# 7935  Sweet Pumpkin            FAQ   FAQ   01-09-2024             2300
# 7936        Brinjal        Brinjal   FAQ   01-09-2024             4700
# 7937  Sweet Pumpkin  Sweet Pumpkin   FAQ   01-09-2024             2000
# 7938         Potato          Jyoti   FAQ   01-09-2024             2300
#
#       Max_x0020_Price  Modal_x0020_Price
# 0                2700             2500.0
# 1                2700             2600.0
# 2                4400             4300.0
# 3                2800             2600.0
# 4                5000             4000.0
# ...               ...                ...
# 7934             8200             8000.0
# 7935             2500             2400.0
# 7936             5200             5000.0
# 7937             2200             2000.0
# 7938             2340             2320.0
#
# [7939 rows x 11 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # New Section

# %%
df['State'].value_counts().keys()
# Out:
# Index(['Tamil Nadu', 'Uttar Pradesh', 'Maharashtra', 'West Bengal',
#        'Madhya Pradesh', 'Haryana', 'Punjab', 'Kerala', 'Telangana', 'Tripura',
#        'Gujarat', 'Odisha', 'Himachal Pradesh', 'Rajasthan', 'Bihar',
#        'Chandigarh', 'Uttrakhand', 'Karnataka', 'Chattisgarh',
#        'Andhra Pradesh'],
#       dtype='object', name='State')

# %%
list(df[df['State'] == 'Andhra Pradesh'].value_counts('Commodity').keys())
# Out:
# ['Tomato']

# %%
df['Grade'] = df['Grade'].replace('FAQ', 'Other')
df.head(40)
# Out:
#     Unnamed: 0             State        District  \
# 0            0             Bihar          Araria
# 1            1             Bihar      Kishanganj
# 2            2             Bihar       Madhubani
# 3            3             Bihar          Rohtas
# 4            4        Chandigarh      Chandigarh
# 5            5           Gujarat          Amreli
# 6            6           Gujarat  Chhota Udaipur
# 7            7           Gujarat          Rajkot
# 8            8           Gujarat          Rajkot
# 9            9           Gujarat          Rajkot
# 10          10           Gujarat          Rajkot
# 11          11           Haryana         Gurgaon
# 12          12           Haryana         Gurgaon
# 13          13           Haryana         Gurgaon
# 14          14           Haryana          Hissar
# 15          15           Haryana          Hissar
# 16          16           Haryana          Hissar
# 17          17           Haryana          Hissar
# 18          18           Haryana          Hissar
# 19          19           Haryana          Hissar
# 20          20           Haryana          Hissar
# 21          21           Haryana          Hissar
# 22          22           Haryana          Hissar
# 23          23           Haryana          Hissar
# 24          24           Haryana          Karnal
# 25          25           Haryana          Karnal
# 26          26           Haryana          Karnal
# 27          27           Haryana          Karnal
# 28          28           Haryana         Sonipat
# 29          29           Haryana         Sonipat
# 30          30           Haryana         Sonipat
# 32                      FAQ   Other   01-09-2024             2000
# 33                      FAQ   Other   01-09-2024             3000
# 34                      FAQ   Other   01-09-2024             1500
# 35                    Apple  Medium   01-09-2024             1500
# 36                      FAQ   Other   01-09-2024              600
# 37                      FAQ   Other   01-09-2024             4200
# 38           Cowpea (Whole)   Other   01-09-2024             7050
# 39                    Gejje   Other   01-09-2024             5950
#
#     Max_x0020_Price  Modal_x0020_Price
# 0              2700             2500.0
# 1              2700             2600.0
# 2              4400             4300.0
# 3              2800             2600.0
# 4              5000             4000.0
# 5              5050             4750.0
# 6              7000             6900.0
# 7             13000             9500.0
# 8              3500             2750.0
# 9              5000             3500.0
# 10              540              510.0
# 11             5000             4000.0
# 12             4000             3000.0
# 13            10000             7500.0
# 14             1500             1400.0
# 15             3500             3300.0
# 16             6000             6000.0
# 17             1500             1500.0
# 18             1000             1000.0
# 19             1500             1500.0
# 20             2200             2200.0
# 21             2600             2300.0
# 22             1500             1200.0
# 23             2000             2000.0
# 24             3000             2250.0
# 25            15000            12500.0
# 26             4000             3400.0
# 27             2000             1900.0
# 28             3000             2800.0
# 29             7000             6500.0
# 30            15000            15000.0
# 31             4000             3500.0
# 32             2600             2200.0
# 33             4000             3500.0
# 34             2600             2500.0
# 35             7000             5000.0
# 36             1400             1000.0
# 37             4600             4500.0
# 38             7860             7500.0
# 39             5950             5950.0

# %%
features = ['State', 'District', 'Market', 'Commodity', 'Variety', 'Grade']
target_min = 'Min_x0020_Price'
target_max = 'Max_x0020_Price'

# %%
X = df[features]
y_min = df[target_min]
y_max = df[target_max]

# %%
encoder = OneHotEncoder()
X_encoded = encoder.fit_transform(X)

# %%
X_train, X_test, y_min_train, y_min_test, y_max_train, y_max_test = train_test_split(X_encoded, y_min, y_max, test_size=0.2, random_state=42)

# %%
models = {
    'Linear Regression': LinearRegression(),
    'Decision Tree': DecisionTreeRegressor(random_state=42),
    'Random Forest': RandomForestRegressor(n_estimators=50, random_state=12)
}


for name, model in models.items():
    print(f"Training and evaluating {name}...")

    # Train the model
    model.fit(X_train, y_min_train)

    print("Training Score : ",model.score(X_train,y_min_train)*100)
    print("Testing Score : ",model.score(X_test,y_min_test)*100)

    print("Training Score : ",model.score(X_train,y_max_train)*100)
    print("Testing Score : ",model.score(X_test,y_max_test)*100)
    print()
# Out:
# Training and evaluating Linear Regression...
# Training Score :  85.25133297834623
# Testing Score :  74.0222856775041
# Training Score :  82.28318963620484
# Testing Score :  73.72600244954101
#
# Training and evaluating Decision Tree...
# Training Score :  100.0
# Testing Score :  69.48286512494732
# Training Score :  94.00070377751321
# Testing Score :  70.97385136002524
#
# Training and evaluating Random Forest...
# Training Score :  96.99691074166655
# Testing Score :  74.61964137175583
# Training Score :  91.74079961035082
# Testing Score :  75.30314812687102

# %%
best_model_name = 'Random Forest'
best_model = models[best_model_name]


new_data = pd.DataFrame({
    'State': ['West Bengal'],
    'District': ['Purba Bardhaman'],
    'Market': ['Memari'],
    'Commodity': ['Sweet Pumpkin'],
    'Variety': ['Sweet Pumpkin'],
    'Grade': ['Other'],
})

encoded_data = encoder.transform(new_data)

predicted_min_price = best_model.predict(encoded_data)
predicted_max_price = best_model.predict(encoded_data)

print(f'Predicted Min Price: {predicted_min_price[0]}')
print(f'Predicted Max Price: {predicted_max_price[0]}')
# Out:
# Predicted Min Price: 2156.0
# Predicted Max Price: 2156.0

# %%
os.makedirs('models',exist_ok=True)
joblib.dump(model,'./models/RandomForest.lb')
joblib.dump(encoder,'./models/Encoder.lb')
# Out:
# ['./models/Encoder.lb']

# %%
df.to_csv('Data_Change.csv')
